# %%
# Recurrent neural networks(RNN)---->unlike traditional neural networks where input are independent of each other rnn handel handels sequential data. in a sentence the
# meaning of 1 word offen depend on the words that came before it . rnn maintain a memory of previous imports using hidden state
# hidden states--->rnn have a loop in there archetecture that allow informtion to be past from 1 stape to the next stape and each time state an rnn takes an input and
# updates a hidden satate that indode both the current inputs and post inputs. the output of eachh stepe depends on the hidden state and the current input .
# recurrent loop---> a rnn can be visualize--->(1)at time state t1--> it takes the input x1 and passes it to a hidden layer which also receves an initial hidedn state
# usually zero
# (2).at time state t2---> the hidden state is updated based on the previous hidden state and the new input x2. so the hidden state is updated . now this process continuous
# dor the length of the sequence
# weight shairing---> rnn use the same set of weights accross all time steps which makes them well suited for sequential data this shared a weight concepts hepls rnn
# generalize well on sequential tasks

# LSTM---> these are design to overcome a mojor limitation of standard rnn's and the issue was vanishing gradient problem this problem makes it difficult for rnn to
# leaarn long terem dependencies in sequence becaiuse as information propogates from any times gradients becomes very small causing the networks to forget earlier
# informations . lstm introduce special mechanism that is called gates that helps model decide which infoemation to remember which to forget and which the output

# structure of LSRM--> (1)cell state-->it is likely a convare belt that runs through the network with only minor linear inter reactions
# GATES-->(1)input gates-- it decides what information do come  (2). forget gate---> it decides what information to through away from the cell state (3) output gate
# ---> it compros what information from the cell state is outout at the current time state
