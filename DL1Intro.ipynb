# %%
# Intrtoduction to deep learning-->

# deep learning is a part of machine learning
# machine learning is used for less complex or non linear data
# deep learning is used for complex or non linear data
# deep lerning is considered as "Representative leaening"
# Deep learning works on human nurvous system. so we use ANN.

# %%
# types of deep learning--->
# (1).Artificial neural network(ANN)---> it is used for tabular data.
# (2).Convolutional neural network(CNN)---> It is used for image related data.
# (3).Recurrent neural network(RNN)--->it is used fo sequential data(i.e text)

# %%
# Workflow of Ml--->
# Data Ingestion--->Data cleaning and preprocessing-->select ml model--->model training--->model prediction--->mocel preformance evaluation

# %%
# Workflow of DL--->
# Data Ingestion--->Data cleaning and Preprocessing--->
# create a model Sequential Archetecture(
    # input_layer(Neurons , Activation_f ,input_dimension),
    # hidden_layer(Neurins , Ativation_fn),
    # output_layer(Neuron , Activation_fn)
# )

# model.complile(loss_fn ,optimizer ,metrics)

# model.training
# model.predicton
# model performance rvaluation ---. total loss,total acuracy.

# %%
# optimizer---> Minimize the loss function(y_act-y_pred)
# Activation_fn---> These are the methematical functions that is used for capture non-linearity
# from the data.

# %%
# How optimizers works in dl---> by the help of chaining rule

# fever(x11)
#                   .x21
# Age(x12)                        .x31--->model training--->model prediction--->result(y)
#                   .x22
# Salary(x13)

# %%
# forward propogation

# x11--->x21--->x31--->y
# x11--->x22--->x31--->y

# x12--->x21--->x31--->y
# x12--->x22--->x31--->y

# x13--->x21--->x31--->y
# x13--->x22--->x31--->y

# %%
# fever(x11)
#                .x21
# Age(x12)                      .x31--->model training--->model prediction--->result(y)
#                .x22
# Salary(x13)

# %%
# Back word propogation-->

# dy/dx11 =  dy/dx31 * dx31/dx21 * dx21/dx11
# dy/dx11 =  dy/dx31 * dx31/dx22 * dx22/dx11

# dy/dx12 =  dy/dx31 * dx31/dx21 * dx21/dx12
# dy/dx12 =  dy/dx31 * dx31/dx22 * dx22/dx12

# dy/dx13 =  dy/dx31 * dx31/dx21 * dx21/dx13
# dy/dx13 =  dy/dx31 * dx31/dx22 * dx22/dx13
